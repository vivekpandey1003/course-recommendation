# %% [markdown]
# # Course Recommendation System Model Building

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datasets/online_courses_updated.csv')

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    user_id  course_id                       course_name       instructor  \
# 0    15796       9366              Python for Beginners      Emma Harris
# 1      861       1928   Cybersecurity for Professionals  Alexander Young
# 2    38159       9541  DevOps and Continuous Deployment   Dr. Mia Walker
# 3    44733       3708   Project Management Fundamentals   Benjamin Lewis
# 4    11285       3361       Ethical Hacking Masterclass     Daniel White
#
#    course_duration_hours certification_offered difficulty_level  rating  \
# 0                   39.1                   Yes         Beginner     5.0
# 1                   36.3                   Yes         Beginner     4.3
# 2                   13.4                   Yes         Beginner     3.9
# 3                   58.3                   Yes         Beginner     3.1
# 4                   30.8                   Yes         Beginner     2.8
#
#    enrollment_numbers  course_price  feedback_score study_material_available  \
# ...

# %%
df['enrollment_numbers'].max(), df['enrollment_numbers'].min()
# Out:
# (49999, 50)

# %%
top_courses_bought = df.groupby(['course_name', 'course_images','rating', 'instructor', 'instructor_images'])['enrollment_numbers'].max().sort_values( ascending=False).reset_index()
top_courses_bought.head(15)
# Out:
#                              course_name  \
# 0   Personal Finance and Wealth Building
# 1         Fitness and Nutrition Coaching
# 2      Mobile App Development with Swift
# 3      Fundamentals of Digital Marketing
# 4                AI for Business Leaders
# 5      Fundamentals of Digital Marketing
# 6   Personal Finance and Wealth Building
# 7                   Python for Beginners
# 8   Personal Finance and Wealth Building
# 9   Personal Finance and Wealth Building
# 10       Project Management Fundamentals
# 11         Photography and Video Editing
# 12   Stock Market and Trading Strategies
# 13        Fitness and Nutrition Coaching
# 14     Mobile App Development with Swift
#
#                                         course_images  rating  \
# 0   https://images.unsplash.com/photo-1554224155-6...     3.7
# 1   https://images.unsplash.com/photo-157101961345...     3.7
# 2   https://images.unsplash.com/photo-163335612254...     4.1
# ...
