# %% [markdown]
# # Course Recommendation System Model Building

# %% [markdown]
# **Popularity Based Technique**
# *A popularity-based recommendation system is essential because it provides a simple and effective way to recommend items when there is little to no user data available `(cold-start problem)`. It suggests the most popular or frequently interacted items (e.g., most watched movies or top-selling products), making it ideal for new users or as a baseline model to compare with more complex systems. It also ensures diversity and general appeal, helping quickly surface trending or universally liked content.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Datasets/online_courses_updated.csv')

# %%
df.shape
# Out:
# (100000, 16)

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df.head()
# Out:
#    user_id  course_id                       course_name       instructor  \
# 0    15796       9366              Python for Beginners      Emma Harris
# 1      861       1928   Cybersecurity for Professionals  Alexander Young
# 2    38159       9541  DevOps and Continuous Deployment   Dr. Mia Walker
# 3    44733       3708   Project Management Fundamentals   Benjamin Lewis
# 4    11285       3361       Ethical Hacking Masterclass     Daniel White
#
#    course_duration_hours certification_offered difficulty_level  rating  \
# 0                   39.1                   Yes         Beginner     5.0
# 1                   36.3                   Yes         Beginner     4.3
# 2                   13.4                   Yes         Beginner     3.9
# 3                   58.3                   Yes         Beginner     3.1
# 4                   30.8                   Yes         Beginner     2.8
#
#    enrollment_numbers  course_price  feedback_score study_material_available  \
# 0               21600        317.50           0.797                      Yes
# 1               15379         40.99           0.770                      Yes
# 2                6431        380.81           0.772                      Yes
# 3               48245        342.80           0.969                       No
# 4               34556        381.01           0.555                      Yes
#
#    time_spent_hours  previous_courses_taken  \
# 0             17.60                       4
# 1             28.97                       9
# 2             52.44                       4
# 3             22.29                       6
# 4             22.01                       5
#
#                                        course_images  \
# 0  https://images.unsplash.com/photo-152637909509...
# 1  https://images.pexels.com/photos/577585/pexels...
# 2  https://images.pexels.com/photos/270404/pexels...
# 3  https://images.unsplash.com/photo-157316471371...
# 4  https://images.unsplash.com/photo-156398676860...
#
#                                    instructor_images
# 0  https://images.pexels.com/photos/712521/pexels...
# 1  https://images.unsplash.com/photo-150064876779...
# 2  https://images.pexels.com/photos/733872/pexels...
# 3  https://images.unsplash.com/photo-151908536075...
# 4  https://images.pexels.com/photos/2379004/pexel...

# %%
## checking for any null values
df.isnull().sum()
# Out:
# user_id                     0
# course_id                   0
# course_name                 0
# instructor                  0
# course_duration_hours       0
# certification_offered       0
# difficulty_level            0
# rating                      0
# enrollment_numbers          0
# course_price                0
# feedback_score              0
# study_material_available    0
# time_spent_hours            0
# previous_courses_taken      0
# course_images               0
# instructor_images           0
# dtype: int64

# %% [markdown]
# **We will consider only those course with respect to the instructor, whose `enrollment_numbers` have exceeded a certain threshold** <br>
# *And we will take threshold as `80%` of the maximum enrollments* <br>
# *that means we will only take those courses, which have enrollments more that or equal to the threshold*

# %%
max_enrollments, min_enrollments = df['enrollment_numbers'].max(), df['enrollment_numbers'].min()
max_enrollments, min_enrollments
# Out:
# (49999, 50)

# %%
threshold_score = max_enrollments * 0.80
threshold_score
# Out:
# 39999.200000000004

# %%
threshold_df = df[df['enrollment_numbers']>=threshold_score]

# %%
threshold_df.head()
# Out:
#     user_id  course_id                           course_name  \
# 3     44733       3708       Project Management Fundamentals
# 6     16851       7887  Networking and System Administration
# 14      770        534         Photography and Video Editing
# 16     5312       3455                  Python for Beginners
# 22     6397       1759        Fitness and Nutrition Coaching
#
#              instructor  course_duration_hours certification_offered  \
# 3        Benjamin Lewis                   58.3                   Yes
# 6      Dr. Robert Davis                   44.9                   Yes
# 14         Daniel White                   74.0                   Yes
# 16       Charlotte King                   11.1                   Yes
# 22  Prof. Emily Johnson                   88.5                    No
#
#    difficulty_level  rating  enrollment_numbers  course_price  feedback_score  \
# 3          Beginner     3.1               48245        342.80           0.969
# 6          Beginner     4.9               41050        389.32           0.893
# 14         Advanced     4.1               40437        388.70           0.620
# 16         Beginner     4.6               43655        426.00           0.966
# 22         Beginner     3.6               44312        178.60           0.598
#
#    study_material_available  time_spent_hours  previous_courses_taken  \
# 3                        No             22.29                       6
# 6                       Yes             15.66                       3
# 14                      Yes             14.13                       3
# 16                      Yes             22.80                       5
# 22                       No             14.45                       1
#
#                                         course_images  \
# 3   https://images.unsplash.com/photo-157316471371...
# 6   https://images.unsplash.com/photo-157316471398...
# 14  https://images.unsplash.com/photo-151603506937...
# 16  https://images.unsplash.com/photo-152637909509...
# 22  https://images.unsplash.com/photo-157101961345...
#
#                                     instructor_images
# 3   https://images.unsplash.com/photo-151908536075...
# 6   https://images.unsplash.com/photo-1545167622-3...
# 14  https://images.pexels.com/photos/2379004/pexel...
# 16  https://images.pexels.com/photos/774909/pexels...
# 22  https://images.pexels.com/photos/38554/girl-pe...

# %%
threshold_df.shape
# Out:
# (20041, 16)

# %% [markdown]
# **We cannot directly get the popularity with respect to number of course bought, we also need to find the average rating with respect to `Course` and `Instructor`, so we need to apply a groupby method.**

# %%
threshold_df['average_rating'] = threshold_df.groupby(['course_name','instructor'])['rating'].transform('mean')
threshold_df.drop_duplicates(subset=['course_name'], inplace=True)
popularity_df = threshold_df.sort_values('average_rating', ascending=False).reset_index().head(25)

# %%
popularity_df.drop(columns=['index'], inplace=True)

# %%
popularity_columns_needed = ['course_name', 'instructor', 'course_duration_hours', 'certification_offered', 'difficulty_level', 'course_price', 'study_material_available', 'course_images', 'instructor_images', 'average_rating']

# %%
popularity_df = popularity_df[popularity_columns_needed]

# %%
popularity_df
# Out:
#                                   course_name           instructor  \
# 0                   Advanced Machine Learning           Liam Adams
# 1        Networking and System Administration     Dr. Robert Davis
# 2                   Graphic Design with Canva     Jessica Martinez
# 3        Personal Finance and Wealth Building        Olivia Taylor
# 4              Fitness and Nutrition Coaching  Prof. Emily Johnson
# 5             Data Visualization with Tableau       Dr. John Smith
# 6                        Python for Beginners       Charlotte King
# 7            DevOps and Continuous Deployment        Michael Brown
# 8                  Cloud Computing Essentials        Olivia Taylor
# 9   Blockchain and Decentralized Applications          Emma Harris
# 10          Mobile App Development with Swift       Isabella Scott
# 11                    Public Speaking Mastery     Jessica Martinez
# 12            Cybersecurity for Professionals        Michael Brown
# 13          Fundamentals of Digital Marketing       Charlotte King
# 14                Game Development with Unity       Dr. Mia Walker
# 15                    AI for Business Leaders       Benjamin Lewis
# 16              Photography and Video Editing         Daniel White
# 17        Stock Market and Trading Strategies     Dr. Robert Davis
# 18                Ethical Hacking Masterclass        Michael Brown
# 19            Project Management Fundamentals       Benjamin Lewis
#
#     course_duration_hours certification_offered difficulty_level  \
# 0                    24.9                    No     Intermediate
# 1                    44.9                   Yes         Beginner
# 2                    11.0                    No         Advanced
# 3                    81.2                   Yes         Advanced
# 4                    88.5                    No         Beginner
# 5                    80.9                   Yes     Intermediate
# 6                    11.1                   Yes         Beginner
# 7                    24.4                   Yes         Beginner
# 8                    63.4                    No         Beginner
# 9                    28.3                   Yes     Intermediate
# 10                   59.3                   Yes         Beginner
# 11                   23.2                   Yes     Intermediate
# 12                   64.9                   Yes         Beginner
# 13                   48.5                   Yes     Intermediate
# 14                    6.1                    No         Advanced
# 15                   33.5                   Yes         Beginner
# 16                   74.0                   Yes         Advanced
# 17                   13.9                    No         Advanced
# 18                   80.5                   Yes         Advanced
# 19                   58.3                   Yes         Beginner
#
#     course_price study_material_available  \
# 0         292.79                      Yes
# 1         389.32                      Yes
# 2         300.29                      Yes
# 3         397.19                      Yes
# 4         178.60                       No
# 5         304.65                      Yes
# 6         426.00                      Yes
# 7          39.57                      Yes
# 8         389.44                      Yes
# 9          32.89                      Yes
# 10        327.75                      Yes
# 11        304.07                      Yes
# 12        412.65                      Yes
# 13        437.36                      Yes
# 14        481.50                      Yes
# 15        308.48                      Yes
# 16        388.70                      Yes
# 17        335.85                      Yes
# 18         57.21                      Yes
# 19        342.80                       No
#
#                                         course_images  \
# 0   https://images.unsplash.com/photo-162071294354...
# 1   https://images.unsplash.com/photo-157316471398...
# 2   https://images.unsplash.com/photo-1547658719-d...
# 3   https://images.unsplash.com/photo-1554224155-6...
# 4   https://images.unsplash.com/photo-157101961345...
# 5   https://images.pexels.com/photos/265087/pexels...
# 6   https://images.unsplash.com/photo-152637909509...
# 7   https://images.pexels.com/photos/270404/pexels...
# 8   https://images.pexels.com/photos/19867468/pexe...
# 9   https://images.pexels.com/photos/14902678/pexe...
# 10  https://images.unsplash.com/photo-163335612254...
# 11  https://images.unsplash.com/photo-143154001516...
# 12  https://images.pexels.com/photos/577585/pexels...
# 13  https://images.unsplash.com/photo-1551288049-b...
# 14  https://images.unsplash.com/photo-1542751371-a...
# 15  https://images.pexels.com/photos/8438974/pexel...
# 16  https://images.unsplash.com/photo-151603506937...
# 17  https://images.unsplash.com/photo-161197478985...
# 18  https://images.unsplash.com/photo-156398676860...
# 19  https://images.unsplash.com/photo-157316471371...
#
#                                     instructor_images  average_rating
# 0   https://images.pexels.com/photos/220453/pexels...        4.118182
# 1   https://images.unsplash.com/photo-1545167622-3...        4.104167
# 2   https://images.pexels.com/photos/1181686/pexel...        4.013725
# 3   https://images.pexels.com/photos/1326946/pexel...        4.004878
# 4   https://images.pexels.com/photos/38554/girl-pe...        4.001818
# 5   https://images.pexels.com/photos/428333/pexels...        3.997872
# 6   https://images.pexels.com/photos/774909/pexels...        3.991071
# 7   https://images.unsplash.com/photo-1560250097-0...        3.981132
# 8   https://images.pexels.com/photos/1326946/pexel...        3.975610
# 9   https://images.pexels.com/photos/712521/pexels...        3.969388
# 10  https://images.unsplash.com/photo-157349635914...        3.952727
# 11  https://images.pexels.com/photos/1181686/pexel...        3.943750
# 12  https://images.unsplash.com/photo-1560250097-0...        3.938298
# 13  https://images.pexels.com/photos/774909/pexels...        3.928571
# 14  https://images.pexels.com/photos/733872/pexels...        3.893750
# 15  https://images.unsplash.com/photo-151908536075...        3.856098
# 16  https://images.pexels.com/photos/2379004/pexel...        3.852174
# 17  https://images.unsplash.com/photo-1545167622-3...        3.848077
# 18  https://images.unsplash.com/photo-1560250097-0...        3.837736
# 19  https://images.unsplash.com/photo-151908536075...        3.776190

# %%
popularity_df.shape
# Out:
# (20, 10)
